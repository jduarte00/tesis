# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Gráficas distribución de los retornos

# %% [markdown]
# ## M. europeo

# %% [markdown]
# valprop

# %%
retornos_90_valprop = pd.read_csv('./results_european/returns_tec_valprop_back_540_periods_90.csv', index_col=0)
retornos_60_valprop = pd.read_csv('./results_european/returns_tec_valprop_back_540_periods_60.csv', index_col=0)
retornos_30_valprop = pd.read_csv('./results_european/returns_tec_valprop_back_540_periods_30.csv', index_col=0)

fig, ax = plt.subplots(1,3)
fig.set_size_inches(20.5, 5)
ax[0].hist(retornos_90_valprop.iloc[362:,0], alpha=0.5, label='rie', fill=False, edgecolor='red', histtype='stepfilled', bins = 100)
ax[0].hist(retornos_90_valprop.iloc[362:,1], alpha=0.5, label='corr. muestral', fill=False, edgecolor='blue', histtype='stepfilled', bins = 100)
ax[0].hist(retornos_90_valprop.iloc[362:,2], alpha=0.5, label='eca', fill=False, edgecolor='orange', histtype='stepfilled', bins = 100)
ax[0].hist(retornos_90_valprop.iloc[362:,3], alpha=0.5, label='pesos igualitarios', fill=False, edgecolor='purple', histtype='stepfilled', bins = 100)
ax[0].legend(loc='upper right')
ax[0].set_title('lookback = 90')

ax[1].hist(retornos_60_valprop.iloc[362:,0], alpha=0.5, label='rie', fill=False, edgecolor='red', histtype='stepfilled', bins = 100)
ax[1].hist(retornos_60_valprop.iloc[362:,1], alpha=0.5, label='corr. muestral', fill=False, edgecolor='blue', histtype='stepfilled', bins = 100)
ax[1].hist(retornos_60_valprop.iloc[362:,2], alpha=0.5, label='eca', fill=False, edgecolor='orange', histtype='stepfilled', bins = 100)
ax[1].hist(retornos_60_valprop.iloc[362:,3], alpha=0.5, label='pesos igualitarios', fill=False, edgecolor='purple', histtype='stepfilled', bins = 100)
ax[1].legend(loc='upper right')
ax[1].set_title('lookback = 60')

ax[2].hist(retornos_30_valprop.iloc[362:,0], alpha=0.5, label='rie', fill=False, edgecolor='red', histtype='stepfilled', bins = 100)
ax[2].hist(retornos_30_valprop.iloc[362:,1], alpha=0.5, label='corr. muestral', fill=False, edgecolor='blue', histtype='stepfilled', bins = 100)
ax[2].hist(retornos_30_valprop.iloc[362:,2], alpha=0.5, label='eca', fill=False, edgecolor='orange', histtype='stepfilled', bins = 100)
ax[2].hist(retornos_30_valprop.iloc[362:,3], alpha=0.5, label='pesos igualitarios', fill=False, edgecolor='purple', histtype='stepfilled', bins = 100)
ax[2].legend(loc='upper right')
ax[2].set_title('lookback = 30');

# %% [markdown]
# Calenski

# %%
retornos_90_valprop = pd.read_csv('./results_european/returns_tec_calenski_back_540_periods_90.csv', index_col=0)
retornos_60_valprop = pd.read_csv('./results_european/returns_tec_calenski_back_540_periods_60.csv', index_col=0)
retornos_30_valprop = pd.read_csv('./results_european/returns_tec_calenski_back_540_periods_30.csv', index_col=0)

fig, ax = plt.subplots(1,3)
fig.set_size_inches(20.5, 5)
ax[0].hist(retornos_90_valprop.iloc[362:,0], alpha=0.5, label='rie', fill=False, edgecolor='red', histtype='stepfilled', bins = 100)
ax[0].hist(retornos_90_valprop.iloc[362:,1], alpha=0.5, label='corr. muestral', fill=False, edgecolor='blue', histtype='stepfilled', bins = 100)
ax[0].hist(retornos_90_valprop.iloc[362:,2], alpha=0.5, label='eca', fill=False, edgecolor='orange', histtype='stepfilled', bins = 100)
ax[0].hist(retornos_90_valprop.iloc[362:,3], alpha=0.5, label='pesos igualitarios', fill=False, edgecolor='purple', histtype='stepfilled', bins = 100)
ax[0].legend(loc='upper right')
ax[0].set_title('lookback = 90')

ax[1].hist(retornos_60_valprop.iloc[362:,0], alpha=0.5, label='rie', fill=False, edgecolor='red', histtype='stepfilled', bins = 100)
ax[1].hist(retornos_60_valprop.iloc[362:,1], alpha=0.5, label='corr. muestral', fill=False, edgecolor='blue', histtype='stepfilled', bins = 100)
ax[1].hist(retornos_60_valprop.iloc[362:,2], alpha=0.5, label='eca', fill=False, edgecolor='orange', histtype='stepfilled', bins = 100)
ax[1].hist(retornos_60_valprop.iloc[362:,3], alpha=0.5, label='pesos igualitarios', fill=False, edgecolor='purple', histtype='stepfilled', bins = 100)
ax[1].legend(loc='upper right')
ax[1].set_title('lookback = 60')

ax[2].hist(retornos_30_valprop.iloc[362:,0], alpha=0.5, label='rie', fill=False, edgecolor='red', histtype='stepfilled', bins = 100)
ax[2].hist(retornos_30_valprop.iloc[362:,1], alpha=0.5, label='corr. muestral', fill=False, edgecolor='blue', histtype='stepfilled', bins = 100)
ax[2].hist(retornos_30_valprop.iloc[362:,2], alpha=0.5, label='eca', fill=False, edgecolor='orange', histtype='stepfilled', bins = 100)
ax[2].hist(retornos_30_valprop.iloc[362:,3], alpha=0.5, label='pesos igualitarios', fill=False, edgecolor='purple', histtype='stepfilled', bins = 100)
ax[2].legend(loc='upper right')
ax[2].set_title('lookback = 30');

# %% [markdown]
# ## M. Americano

# %% [markdown]
# valprop

# %%
retornos_90_valprop = pd.read_csv('./results_american/returns_tec_valprop_back_920_periods_90.csv', index_col=0)
retornos_60_valprop = pd.read_csv('./results_american/returns_tec_valprop_back_920_periods_60.csv', index_col=0)
retornos_30_valprop = pd.read_csv('./results_american/returns_tec_valprop_back_920_periods_30.csv', index_col=0)

fig, ax = plt.subplots(1,3)
fig.set_size_inches(20.5, 5)
ax[0].hist(retornos_90_valprop.iloc[362:,0], alpha=0.5, label='rie', fill=False, edgecolor='red', histtype='stepfilled', bins = 100)
ax[0].hist(retornos_90_valprop.iloc[362:,1], alpha=0.5, label='corr. muestral', fill=False, edgecolor='blue', histtype='stepfilled', bins = 100)
ax[0].hist(retornos_90_valprop.iloc[362:,2], alpha=0.5, label='eca', fill=False, edgecolor='orange', histtype='stepfilled', bins = 100)
ax[0].hist(retornos_90_valprop.iloc[362:,3], alpha=0.5, label='pesos igualitarios', fill=False, edgecolor='purple', histtype='stepfilled', bins = 100)
ax[0].legend(loc='upper right')
ax[0].set_title('lookback = 90')

ax[1].hist(retornos_60_valprop.iloc[362:,0], alpha=0.5, label='rie', fill=False, edgecolor='red', histtype='stepfilled', bins = 100)
ax[1].hist(retornos_60_valprop.iloc[362:,1], alpha=0.5, label='corr. muestral', fill=False, edgecolor='blue', histtype='stepfilled', bins = 100)
ax[1].hist(retornos_60_valprop.iloc[362:,2], alpha=0.5, label='eca', fill=False, edgecolor='orange', histtype='stepfilled', bins = 100)
ax[1].hist(retornos_60_valprop.iloc[362:,3], alpha=0.5, label='pesos igualitarios', fill=False, edgecolor='purple', histtype='stepfilled', bins = 100)
ax[1].legend(loc='upper right')
ax[1].set_title('lookback = 60')

ax[2].hist(retornos_30_valprop.iloc[362:,0], alpha=0.5, label='rie', fill=False, edgecolor='red', histtype='stepfilled', bins = 100)
ax[2].hist(retornos_30_valprop.iloc[362:,1], alpha=0.5, label='corr. muestral', fill=False, edgecolor='blue', histtype='stepfilled', bins = 100)
ax[2].hist(retornos_30_valprop.iloc[362:,2], alpha=0.5, label='eca', fill=False, edgecolor='orange', histtype='stepfilled', bins = 100)
ax[2].hist(retornos_30_valprop.iloc[362:,3], alpha=0.5, label='pesos igualitarios', fill=False, edgecolor='purple', histtype='stepfilled', bins = 100)
ax[2].legend(loc='upper right')
ax[2].set_title('lookback = 30');

# %% [markdown]
# Calenski

# %%
retornos_90_valprop = pd.read_csv('./results_american/returns_tec_calenski_back_920_periods_90.csv', index_col=0)
retornos_60_valprop = pd.read_csv('./results_american/returns_tec_calenski_back_920_periods_60.csv', index_col=0)
retornos_30_valprop = pd.read_csv('./results_american/returns_tec_calenski_back_920_periods_30.csv', index_col=0)

fig, ax = plt.subplots(1,3)
fig.set_size_inches(20.5, 5)
ax[0].hist(retornos_90_valprop.iloc[362:,0], alpha=0.5, label='rie', fill=False, edgecolor='red', histtype='stepfilled', bins = 100)
ax[0].hist(retornos_90_valprop.iloc[362:,1], alpha=0.5, label='corr. muestral', fill=False, edgecolor='blue', histtype='stepfilled', bins = 100)
ax[0].hist(retornos_90_valprop.iloc[362:,2], alpha=0.5, label='eca', fill=False, edgecolor='orange', histtype='stepfilled', bins = 100)
ax[0].hist(retornos_90_valprop.iloc[362:,3], alpha=0.5, label='pesos igualitarios', fill=False, edgecolor='purple', histtype='stepfilled', bins = 100)
ax[0].legend(loc='upper right')
ax[0].set_title('lookback = 90')

ax[1].hist(retornos_60_valprop.iloc[362:,0], alpha=0.5, label='rie', fill=False, edgecolor='red', histtype='stepfilled', bins = 100)
ax[1].hist(retornos_60_valprop.iloc[362:,1], alpha=0.5, label='corr. muestral', fill=False, edgecolor='blue', histtype='stepfilled', bins = 100)
ax[1].hist(retornos_60_valprop.iloc[362:,2], alpha=0.5, label='eca', fill=False, edgecolor='orange', histtype='stepfilled', bins = 100)
ax[1].hist(retornos_60_valprop.iloc[362:,3], alpha=0.5, label='pesos igualitarios', fill=False, edgecolor='purple', histtype='stepfilled', bins = 100)
ax[1].legend(loc='upper right')
ax[1].set_title('lookback = 60')

ax[2].hist(retornos_30_valprop.iloc[362:,0], alpha=0.5, label='rie', fill=False, edgecolor='red', histtype='stepfilled', bins = 100)
ax[2].hist(retornos_30_valprop.iloc[362:,1], alpha=0.5, label='corr. muestral', fill=False, edgecolor='blue', histtype='stepfilled', bins = 100)
ax[2].hist(retornos_30_valprop.iloc[362:,2], alpha=0.5, label='eca', fill=False, edgecolor='orange', histtype='stepfilled', bins = 100)
ax[2].hist(retornos_30_valprop.iloc[362:,3], alpha=0.5, label='pesos igualitarios', fill=False, edgecolor='purple', histtype='stepfilled', bins = 100)
ax[2].legend(loc='upper right')
ax[2].set_title('lookback = 30');

# %% [markdown]
# # Gráficas cambio grupos tiempo

# %% [markdown]
# ## M Europeo

# %% [markdown]
# ### calenksi

# %%
rie_data_90 = pd.read_csv('./results_european/clusters_rie_tec_calenski_back_540_periods_90.csv', index_col='date', parse_dates=True)
corr_data_90 = pd.read_csv('./results_european/clusters_corr_tec_calenski_back_540_periods_90.csv', index_col='date', parse_dates=True)
clust_data_90 = pd.read_csv('./results_european/clusters_clust_tec_calenski_back_540_periods_90.csv', index_col='date', parse_dates=True)

rie_data_60 = pd.read_csv('./results_european/clusters_rie_tec_calenski_back_540_periods_60.csv', index_col='date', parse_dates=True)
corr_data_60 = pd.read_csv('./results_european/clusters_corr_tec_calenski_back_540_periods_60.csv', index_col='date', parse_dates=True)
clust_data_60 = pd.read_csv('./results_european/clusters_clust_tec_calenski_back_540_periods_60.csv', index_col='date', parse_dates=True)

rie_data_30 = pd.read_csv('./results_european/clusters_rie_tec_calenski_back_540_periods_30.csv', index_col='date', parse_dates=True)
corr_data_30 = pd.read_csv('./results_european/clusters_corr_tec_calenski_back_540_periods_30.csv', index_col='date', parse_dates=True)
clust_data_30 = pd.read_csv('./results_european/clusters_clust_tec_calenski_back_540_periods_30.csv', index_col='date', parse_dates=True)
fig, ax = plt.subplots(1,3)
fig.set_size_inches(20.5, 5)
idx = pd.date_range('2013-06-25', '2021-12-10')
rie_clust_complete = rie_data_90.reindex(idx, method = 'ffill')
corr_clust_complete = corr_data_90.reindex(idx, method = 'ffill')
clust_clust_complete = clust_data_90.reindex(idx, method = 'ffill')
ax[0].plot(corr_clust_complete['n_clusters'], label = 'Corr', alpha = 0.4)
ax[0].plot(clust_clust_complete['n_clusters'], label = 'ECA', alpha = 0.4)
ax[0].plot(rie_clust_complete['n_clusters'], label = 'RIE', alpha = 0.4)
ax[0].legend(loc='upper right')
ax[0].set_title('lookback = 90')

rie_clust_complete = rie_data_60.reindex(idx, method = 'ffill')
corr_clust_complete = corr_data_60.reindex(idx, method = 'ffill')
clust_clust_complete = clust_data_60.reindex(idx, method = 'ffill')
ax[1].plot(corr_clust_complete['n_clusters'], label = 'Corr', alpha = 0.4)
ax[1].plot(clust_clust_complete['n_clusters'], label = 'ECA', alpha = 0.4)
ax[1].plot(rie_clust_complete['n_clusters'], label = 'RIE', alpha = 0.4)
ax[1].legend(loc='upper right')
ax[1].set_title('lookback = 60')

rie_clust_complete = rie_data_30.reindex(idx, method = 'ffill')
corr_clust_complete = corr_data_30.reindex(idx, method = 'ffill')
clust_clust_complete = clust_data_30.reindex(idx, method = 'ffill')
ax[2].plot(corr_clust_complete['n_clusters'], label = 'Corr', alpha = 0.4)
ax[2].plot(clust_clust_complete['n_clusters'], label = 'ECA', alpha = 0.4)
ax[2].plot(rie_clust_complete['n_clusters'], label = 'RIE', alpha = 0.4)
ax[2].legend(loc='upper right')
ax[2].set_title('lookback = 30');

# %% [markdown]
# ### val prop

# %%
rie_data_90 = pd.read_csv('./results_european/clusters_rie_tec_valprop_back_540_periods_90.csv', index_col='date', parse_dates=True)
corr_data_90 = pd.read_csv('./results_european/clusters_corr_tec_valprop_back_540_periods_90.csv', index_col='date', parse_dates=True)
clust_data_90 = pd.read_csv('./results_european/clusters_clust_tec_valprop_back_540_periods_90.csv', index_col='date', parse_dates=True)

rie_data_60 = pd.read_csv('./results_european/clusters_rie_tec_valprop_back_540_periods_60.csv', index_col='date', parse_dates=True)
corr_data_60 = pd.read_csv('./results_european/clusters_corr_tec_valprop_back_540_periods_60.csv', index_col='date', parse_dates=True)
clust_data_60 = pd.read_csv('./results_european/clusters_clust_tec_valprop_back_540_periods_60.csv', index_col='date', parse_dates=True)

rie_data_30 = pd.read_csv('./results_european/clusters_rie_tec_valprop_back_540_periods_30.csv', index_col='date', parse_dates=True)
corr_data_30 = pd.read_csv('./results_european/clusters_corr_tec_valprop_back_540_periods_30.csv', index_col='date', parse_dates=True)
clust_data_30 = pd.read_csv('./results_european/clusters_clust_tec_valprop_back_540_periods_30.csv', index_col='date', parse_dates=True)
fig, ax = plt.subplots(1,3)
fig.set_size_inches(20.5, 5)
idx = pd.date_range('2013-06-25', '2021-12-10')
rie_clust_complete = rie_data_90.reindex(idx, method = 'ffill')
corr_clust_complete = corr_data_90.reindex(idx, method = 'ffill')
clust_clust_complete = clust_data_90.reindex(idx, method = 'ffill')
ax[0].plot(corr_clust_complete['n_clusters'], label = 'Corr', alpha = 0.4)
ax[0].plot(clust_clust_complete['n_clusters'], label = 'ECA', alpha = 0.4)
ax[0].plot(rie_clust_complete['n_clusters'], label = 'RIE', alpha = 0.4)
ax[0].legend(loc='upper right')
ax[0].set_title('lookback = 90')

rie_clust_complete = rie_data_60.reindex(idx, method = 'ffill')
corr_clust_complete = corr_data_60.reindex(idx, method = 'ffill')
clust_clust_complete = clust_data_60.reindex(idx, method = 'ffill')
ax[1].plot(corr_clust_complete['n_clusters'], label = 'Corr', alpha = 0.4)
ax[1].plot(clust_clust_complete['n_clusters'], label = 'ECA', alpha = 0.4)
ax[1].plot(rie_clust_complete['n_clusters'], label = 'RIE', alpha = 0.4)
ax[1].legend(loc='upper right')
ax[1].set_title('lookback = 60')

rie_clust_complete = rie_data_30.reindex(idx, method = 'ffill')
corr_clust_complete = corr_data_30.reindex(idx, method = 'ffill')
clust_clust_complete = clust_data_30.reindex(idx, method = 'ffill')
ax[2].plot(corr_clust_complete['n_clusters'], label = 'Corr', alpha = 0.4)
ax[2].plot(clust_clust_complete['n_clusters'], label = 'ECA', alpha = 0.4)
ax[2].plot(rie_clust_complete['n_clusters'], label = 'RIE', alpha = 0.4)
ax[2].legend(loc='upper right')
ax[2].set_title('lookback = 30');

# %% [markdown]
# ## M Americano

# %% [markdown]
# ### Calenski

# %%
#[TESIS]

rie_data_90 = pd.read_csv('./results_american/clusters_rie_tec_calenski_back_920_periods_90.csv', index_col='date', parse_dates=True)
corr_data_90 = pd.read_csv('./results_american/clusters_corr_tec_calenski_back_920_periods_90.csv', index_col='date', parse_dates=True)
clust_data_90 = pd.read_csv('./results_american/clusters_clust_tec_calenski_back_920_periods_90.csv', index_col='date', parse_dates=True)

rie_data_60 = pd.read_csv('./results_american/clusters_rie_tec_calenski_back_920_periods_60.csv', index_col='date', parse_dates=True)
corr_data_60 = pd.read_csv('./results_american/clusters_corr_tec_calenski_back_920_periods_60.csv', index_col='date', parse_dates=True)
clust_data_60 = pd.read_csv('./results_american/clusters_clust_tec_calenski_back_920_periods_60.csv', index_col='date', parse_dates=True)

rie_data_30 = pd.read_csv('./results_american/clusters_rie_tec_calenski_back_920_periods_30.csv', index_col='date', parse_dates=True)
corr_data_30 = pd.read_csv('./results_american/clusters_corr_tec_calenski_back_920_periods_30.csv', index_col='date', parse_dates=True)
clust_data_30 = pd.read_csv('./results_american/clusters_clust_tec_calenski_back_920_periods_30.csv', index_col='date', parse_dates=True)
fig, ax = plt.subplots(1,3)
fig.set_size_inches(20.5, 5)
idx = pd.date_range('2013-06-25', '2021-12-10')
rie_clust_complete = rie_data_90.reindex(idx, method = 'ffill')
corr_clust_complete = corr_data_90.reindex(idx, method = 'ffill')
clust_clust_complete = clust_data_90.reindex(idx, method = 'ffill')
ax[0].plot(corr_clust_complete['n_clusters'], label = 'Corr', alpha = 0.4)
ax[0].plot(clust_clust_complete['n_clusters'], label = 'ECA', alpha = 0.4)
ax[0].plot(rie_clust_complete['n_clusters'], label = 'RIE', alpha = 0.4)
ax[0].legend(loc='lower right')
ax[0].set_title('lookback = 90')

rie_clust_complete = rie_data_60.reindex(idx, method = 'ffill')
corr_clust_complete = corr_data_60.reindex(idx, method = 'ffill')
clust_clust_complete = clust_data_60.reindex(idx, method = 'ffill')
ax[1].plot(corr_clust_complete['n_clusters'], label = 'Corr', alpha = 0.4)
ax[1].plot(clust_clust_complete['n_clusters'], label = 'ECA', alpha = 0.4)
ax[1].plot(rie_clust_complete['n_clusters'], label = 'RIE', alpha = 0.4)
ax[1].legend(loc='upper right')
ax[1].set_title('lookback = 60')

rie_clust_complete = rie_data_30.reindex(idx, method = 'ffill')
corr_clust_complete = corr_data_30.reindex(idx, method = 'ffill')
clust_clust_complete = clust_data_30.reindex(idx, method = 'ffill')
ax[2].plot(corr_clust_complete['n_clusters'], label = 'Corr', alpha = 0.4)
ax[2].plot(clust_clust_complete['n_clusters'], label = 'ECA', alpha = 0.4)
ax[2].plot(rie_clust_complete['n_clusters'], label = 'RIE', alpha = 0.4)
ax[2].legend(loc='upper right')
ax[2].set_title('lookback = 30');

# %%
#[TESIS]

rie_data_90 = pd.read_csv('./results_american/clusters_rie_tec_valprop_back_920_periods_90.csv', index_col='date', parse_dates=True)
corr_data_90 = pd.read_csv('./results_american/clusters_corr_tec_valprop_back_920_periods_90.csv', index_col='date', parse_dates=True)
clust_data_90 = pd.read_csv('./results_american/clusters_clust_tec_valprop_back_920_periods_90.csv', index_col='date', parse_dates=True)

rie_data_60 = pd.read_csv('./results_american/clusters_rie_tec_valprop_back_920_periods_60.csv', index_col='date', parse_dates=True)
corr_data_60 = pd.read_csv('./results_american/clusters_corr_tec_valprop_back_920_periods_60.csv', index_col='date', parse_dates=True)
clust_data_60 = pd.read_csv('./results_american/clusters_clust_tec_valprop_back_920_periods_60.csv', index_col='date', parse_dates=True)

rie_data_30 = pd.read_csv('./results_american/clusters_rie_tec_valprop_back_920_periods_30.csv', index_col='date', parse_dates=True)
corr_data_30 = pd.read_csv('./results_american/clusters_corr_tec_valprop_back_920_periods_30.csv', index_col='date', parse_dates=True)
clust_data_30 = pd.read_csv('./results_american/clusters_clust_tec_valprop_back_920_periods_30.csv', index_col='date', parse_dates=True)
fig, ax = plt.subplots(1,3)
fig.set_size_inches(20.5, 5)
idx = pd.date_range('2013-06-25', '2021-12-10')
rie_clust_complete = rie_data_90.reindex(idx, method = 'ffill')
corr_clust_complete = corr_data_90.reindex(idx, method = 'ffill')
clust_clust_complete = clust_data_90.reindex(idx, method = 'ffill')
ax[0].plot(corr_clust_complete['n_clusters'], label = 'Corr', alpha = 0.4)
ax[0].plot(clust_clust_complete['n_clusters'], label = 'ECA', alpha = 0.4)
ax[0].plot(rie_clust_complete['n_clusters'], label = 'RIE', alpha = 0.4)
ax[0].legend(loc='upper left')
ax[0].set_title('lookback = 90')

rie_clust_complete = rie_data_60.reindex(idx, method = 'ffill')
corr_clust_complete = corr_data_60.reindex(idx, method = 'ffill')
clust_clust_complete = clust_data_60.reindex(idx, method = 'ffill')
ax[1].plot(corr_clust_complete['n_clusters'], label = 'Corr', alpha = 0.4)
ax[1].plot(clust_clust_complete['n_clusters'], label = 'ECA', alpha = 0.4)
ax[1].plot(rie_clust_complete['n_clusters'], label = 'RIE', alpha = 0.4)
ax[1].legend(loc='upper right')
ax[1].set_title('lookback = 60')

rie_clust_complete = rie_data_30.reindex(idx, method = 'ffill')
corr_clust_complete = corr_data_30.reindex(idx, method = 'ffill')
clust_clust_complete = clust_data_30.reindex(idx, method = 'ffill')
ax[2].plot(corr_clust_complete['n_clusters'], label = 'Corr', alpha = 0.4)
ax[2].plot(clust_clust_complete['n_clusters'], label = 'ECA', alpha = 0.4)
ax[2].plot(rie_clust_complete['n_clusters'], label = 'RIE', alpha = 0.4)
ax[2].legend(loc='upper left')
ax[2].set_title('lookback = 30');

# %% [markdown]
# # Gráficas rendimiento acumulado

# %% [markdown]
# Se muestran solo los rendimientos acumulados de los mejores portafolios
